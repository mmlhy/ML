# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %%
data = pd.Series(np.random.randn(1000),index=np.arange(1000))
data = data.cumsum()#累加
data.plot()
plt.show()

# %%
data = pd.DataFrame(np.random.randn(1000,4),index = np.arange(1000),columns=['A','B','C','D'])
data = data.cumsum()
print(data.head())
data.plot()
plt.show()
# Out:
#           A         B         C         D
# 0  1.530927  1.652533 -0.897930  0.618075
# 1  3.549363  0.210378 -1.101871 -0.299952
# 2  3.842388  0.974815 -1.269667  2.137223
# 3  2.560654  0.748169 -1.878374  2.671226
# 4  2.358343 -0.334159 -2.094694 -0.560268

# %%
ax = data.plot.scatter(x='A',y='B',color='Blue',label='class 1')
data.plot.scatter(x='A',y='C',color='Green',label='class 2',ax=ax)
plt.show()
